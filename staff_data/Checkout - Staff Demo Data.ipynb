# %%
import pandas as pd
import requests
from bs4 import BeautifulSoup as bs
import re
import os
import glob

# %%
## First, get list of staff codes

# %%
resp = requests.get("http://profiles.doe.mass.edu/state_report/teacherbyracegender.aspx")
html = resp.content
soup = bs(html, "html.parser")

# %%
options = soup.find_all("option")


options[18]["value"], options[18].text
# Out:
# ('1100', 'All')

# %%
value = []
jobs = []

for o in options:
    id = (o["value"])
    job = (o.text)
    value.append(id)
    jobs.append(job)


job_codes = value[18:]
jobs = jobs[18:]

job_classes = dict(zip(job_codes, jobs))

job_codes

years = value[4:14]

# %%
job_classes
# Out:
# {'1100': 'All',
#  '1200': 'Superintendent of Schools',
#  '1201': 'Assistant/Associate/ Vice Superintendents',
#  '1202': 'School Business Official',
#  '1205': 'Other District Wide Administrators',
#  '1210': 'Supervisor/Director of Guidance',
#  '1211': 'Supervisor/Director of Pupil Personnel',
#  '1212': 'Special Education Administrator',
#  '1213': 'Supervisor/Director/Coordinator: Arts',
#  '1214': 'Supervisor/Director/Coordinator of Assessment',
#  '1215': 'Supervisor/Director/Coordinator of Curriculum',
#  '1216': 'Supervisor/Director/Coordinator: English Language Learner',
#  '1217': 'Supervisor/Director/Coordinator: English',
#  '1218': 'Supervisor/Director/Coordinator: Foreign Language',
#  '1219': 'Supervisor/Director/Coordinator: History/Social Studies',
#  '1220': 'Supervisor/Director/Coordinator: Library/Media',
#  '1221': 'Supervisor/Director/Coordinator: Mathematics',
#  '1222': 'Supervisor/Director/Coordinator: Reading',
#  '1223': 'Supervisor/Director/Coordinator: Science',
#  '1224': 'Supervisor/Director/Coordinator: Technology',
#  '1225': 'Supervisor/Director/Coordinator of Professional Development',
#  '1226': 'School Nurse Leader',
#  '1305': 'Principal/headmaster/headmistress/head of school',
#  '1310': 'Deputy/Associate/Vice-/Assistant Principal',
#  '1312': 'School Special Education Administrator',
#  '1320': 'Other School Administrator/Coordinator',
#  '2305': 'Teacher',
#  '2306': 'Co-teacher',
#  '2307': 'Virtual Course Teacher',
#  '2308': 'Virtual Course Co-Teacher',
#  '2310': 'Teacher - support content instruction',
#  '2325': 'Long Term Substitute Teacher',
#  '2330': 'Instructional Coach',
#  '3323': 'Tutor',
#  '3324': 'Educational Interpreters',
#  '3325': 'Diagnostic and Evaluation Staff',
#  '3326': 'Recreation and Therapeutic Recreation Specialists',
#  '3327': 'Rehabilitation Counselor',
#  '3328': 'Work Study Coordinator',
#  '3329': 'Guidance Counselor',
#  '3330': 'Librarians and Media Center Directors',
#  '3340': 'Junior ROTC Instructor',
#  '3350': 'School Adjustment Counselor -- Non-Special Education',
#  '3351': 'School Adjustment Counselor -- Special Education',
#  '3360': 'School Psychologist -- Non-Special Education',
#  '3361': 'School Psychologist -- Special Education',
#  '3370': 'School Social Worker -- Non-Special Education',
#  '3371': 'School Social Worker  -- Special Education',
#  '3411': 'Audiologist',
#  '3421': 'Occupational Therapist',
#  '3431': 'Physical Therapist',
#  '3441': 'Orientation and Mobility Instructor (Peripatologist)',
#  '3451': 'Speech Pathologist',
#  '3461': 'Other Related Special Education Staff',
#  '4100': 'Paraprofessional',
#  '5010': 'Physician',
#  '5015': 'Psychiatrist',
#  '5020': 'School Nurse -- Non-Special Education',
#  '5021': 'School Nurse -- Special Education',
#  '6100': 'Administrative Aides',
#  '6110': 'Administrative Clerks and Secretaries',
#  '6120': 'Special Education Administrative Aides',
#  '6130': 'Special Education Administrative Clerks and Secretaries',
#  '6140': 'Information Services & Technical Support',
#  '6150': 'Other Administrative Support Personnel'}

# %%
## Write all staff race-ethnicity files

# %%
for year in years:
    for code in job_codes:
        base = 'http://profiles.doe.mass.edu/state_report/teacherbyracegender.aspx?ctl00$ContentPlaceHolder1$fycode={}&export_excel=yes&ctl00$ContentPlaceHolder1$displayType=NUM&ctl00$ContentPlaceHolder1$jobClass={}&ctl00$ContentPlaceHolder1$reportType=SCHOOL'
        base = base.format(year, code)
        filename = "staff_"+"raceeth_"+str(year)+"_"+str(code)+".xls"
        with open(filename, 'w') as output:
            output.write(requests.get(base).text)

# %%
## Bind all xls files together (2010 to 2017) Just do 2013 first

# %%
def clean_file(file):
    df = pd.read_html(file)
    df = pd.DataFrame(df[1])
    header = df.iloc[0]
    try:
        df.columns = header
        df = df[1:]
        df.set_index('Org Code')
        file_name = os.path.splitext(file)[0]
        df["Source"] = file_name
        return df
    except:
        print("No data in file")

# %%
all_files = glob.glob("staff_raceeth_2011_*.xls")
all_files

# %%
all_files = glob.glob("staff_raceeth_2011_*.xls")
df_list = []

for file in all_files:
    print(file)
    file = clean_file(file)
    df_list.append(file)

# %%
df = pd.concat(df_list)

# %%
## Add additional columns and export to csv
df['Job Code'] = df["Source"].str[-4:]
df['Year'] = df["Source"].str[-9:-5]
df = df.set_index('Org Code')

# %%
df

# %%
df.to_csv("staff_raceeth_jobcodes_2011.csv")

# %%
df['Job Group'] = df['Job Code'].str[0:2]

# %%
num_cols = ["African American (# )","Asian (# )", "Hispanic (# )", "White (# )", "Native Hawaiian, Pacific Islander (# )", "Native American (# )", "Multi-Race, Non-Hispanic (# )", "FTE Count"]
df[num_cols] = df[num_cols].apply(pd.to_numeric)
df_grouped = df.groupby(['Job Group','Year', "Org Code", "SCHOOL"])[num_cols].sum()

df_grouped

# %%
df_grouped = df_grouped.reset_index()
df_grouped = df_grouped.set_index('Org Code')
df_grouped["Other (# )"] = df_grouped["Native Hawaiian, Pacific Islander (# )"] + df_grouped["Native American (# )"] + df_grouped["Multi-Race, Non-Hispanic (# )"] 
df_grouped.drop(['Native Hawaiian, Pacific Islander (# )', 'Native American (# )', 'Multi-Race, Non-Hispanic (# )' ], axis=1, inplace=True)

# %%
df_grouped.to_csv("staff_raceeth_jobcategories_2011.csv")

# %%
## bind grouped staff csvs together and join with job code category names

# %%
filenames = glob.glob("staff_raceeth_jobcategories_201[1-5].csv")
dfs = []
for filename in filenames:
    dfs.append(pd.read_csv(filename))

# Concatenate all data into one DataFrame
job_categories = pd.concat(dfs)
job_categories
# Out:
#        Org Code  Job Group  Year  \
# 0         10003         11  2011
# 1         10015         11  2011
# 2         10405         11  2011
# 3         10505         11  2011
# 4         20010         11  2011
# 5         20015         11  2011
# 6         20020         11  2011
# 7         20025         11  2011
# 8         20030         11  2011
# 9         30025         11  2011
# 10        30305         11  2011
# 11        50003         11  2011
# 12        50010         11  2011
# 13        50020         11  2011
# 14        50025         11  2011
# 15        50030         11  2011
# 16        50303         11  2011
# 17        50405         11  2011
# 18        50505         11  2011
# 19        70005         11  2011
# 20        70010         11  2011
# 21        70013         11  2011
# 22        70505         11  2011
# 23        80009         11  2011
# 24        80020         11  2011
# 25        80050         11  2011
# 26        90003         11  2011
# 27        90004         11  2011
# 28        90005         11  2011
# 29        90010         11  2011
# ...         ...        ...   ...
# 16719   8250605         61  2015
# 16720   8280605         61  2015
# 16721   8290605         61  2015
# 16722   8300605         61  2015
# 16723   8320605         61  2015
# 16724   8510605         61  2015
# 16725   8520605         61  2015
# 16726   8530605         61  2015
# 16727   8550605         61  2015
# 16728   8600605         61  2015
# 16729   8710605         61  2015
# 16730   8720605         61  2015
# 16731   8730605         61  2015
# 16732   8760605         61  2015
# 16733   8780605         61  2015
# 16734   8790605         61  2015
# 16735   8850605         61  2015
# 16736   9100705         61  2015
# 16737   9150705         61  2015
# 16738  35010505         61  2015
# 16739  35020405         61  2015
# 16740  35030205         61  2015
# 16741  35040505         61  2015
# 16742  35050405         61  2015
# 16743  35060505         61  2015
# 16744  35070505         61  2015
# 16745  35080505         61  2015
# 16746  35090305         61  2015
# 16747  39010900         61  2015
# 16748  39020900         61  2015
#
#                                                   SCHOOL  \
# 0                                Abington - Abington ECC
# 1                                   Abington - Woodsdale
# 2                        Abington - Frolio Middle School
# 3                               Abington - Abington High
# 4                                        Acton - Merriam
# 5                                 Acton - McCarthy-Towne
# 6                                        Acton - Douglas
# 7                                          Acton - Gates
# 8                                  Acton - Luther Conant
# 9                     Acushnet - Acushnet Elementary Sch
# 10                   Acushnet - Albert F Ford Middle Sch
# 11                                   Agawam - Agawam ECC
# 12                           Agawam - Clifford M Granger
# 13                            Agawam - Benjamin J Phelps
# 14                                Agawam - Robinson Park
# 15                           Agawam - James Clark School
# 16                    Agawam - Roberta G. Doering School
# 17                           Agawam - Agawam Junior High
# 18                                  Agawam - Agawam High
# 19                        Amesbury - Amesbury Elementary
# 20                       Amesbury - Charles C Cashman El
# 21                            Amesbury - Amesbury Middle
# 22                              Amesbury - Amesbury High
# 23                     Amherst - Crocker Farm Elementary
# 24                       Amherst - Fort River Elementary
# 25                         Amherst - Wildwood Elementary
# 26                         Andover - Bancroft Elementary
# 27                       Andover - High Plain Elementary
# 28                            Andover - Shawsheen School
# 29                        Andover - Henry C Sanborn Elem
# ...                                                  ...
# 16719  Greater New Bedford Regional Vocational Techni...
# 16720  Greater Lowell Regional Vocational Technical -...
# 16721  South Middlesex Regional Vocational Technical ...
# 16722  Minuteman Regional Vocational Technical - Minu...
# 16723  Montachusett Regional Vocational Technical - M...
# 16724  Northern Berkshire Regional Vocational Technic...
# 16725  Nashoba Valley Regional Vocational Technical -...
# 16726  Northeast Metropolitan Regional Vocational Tec...
# 16727  Old Colony Regional Vocational Technical - Old...
# 16728  Pathfinder Regional Vocational Technical - Pat...
# 16729  Shawsheen Valley Regional Vocational Technical...
# 16730  Southeastern Regional Vocational Technical - S...
# 16731  South Shore Regional Vocational Technical - So...
# 16732  Southern Worcester County Regional Vocational ...
# 16733  Tri County Regional Vocational Technical - Tri...
# 16734  Upper Cape Cod Regional Vocational Technical -...
# 16735  Whittier Regional Vocational Technical - Whitt...
# 16736  Bristol County Agricultural - Bristol County A...
# 16737  Norfolk County Agricultural - Norfolk County A...
# 16738  Paulo Freire Social Justice Charter School (Di...
# 16739  Baystate Academy Charter Public School (Distri...
# 16740  Lowell Collegiate Charter School (District) - ...
# 16741  City on a Hill Charter Public School Dudley Sq...
# 16742  UP Academy Charter School of Dorchester (Distr...
# 16743  Pioneer Charter School of Science II (PCSS-II)...
# 16744  City on a Hill Charter Public School New Bedfo...
# 16745  Phoenix Academy Public Charter High School Spr...
# 16746  Argosy Collegiate Charter School (District) - ...
# 16747  Massachusetts Virtual Academy at Greenfield Co...
# 16748  TEC Connections Academy Commonwealth Virtual S...
#
#        African American (# )  Asian (# )  Hispanic (# )  White (# )  \
# 0                        1.0         0.0            0.0        68.6
# 1                        2.0         0.0            0.0        37.8
# 2                        0.0         0.0            0.0        29.5
# 3                        1.0         0.0            1.0        49.6
# 4                        0.0         2.0            0.0        80.5
# 5                        0.0         0.0            0.0        58.8
# 6                        0.0         0.2            0.0        48.3
# 7                        0.0         1.5            0.0        47.9
# 8                        0.0         2.2            0.0        56.0
# 9                        0.0         0.0            0.0        60.3
# 10                       0.0         0.0            0.0        48.1
# 11                       1.0         0.0            0.0        28.8
# 12                       0.0         0.0            0.0        48.0
# 13                       0.0         0.0            0.0        49.1
# 14                       0.0         0.0            0.0        59.9
# 15                       0.0         0.0            0.0        58.0
# 16                       1.0         0.0            1.0        76.0
# 17                       0.0         0.0            0.0        89.1
# 18                       0.0         0.0            2.0       131.7
# 19                       0.0         0.0            0.0        56.0
# 20                       0.0         0.0            0.0        57.3
# 21                       0.5         0.0            2.0        80.6
# 22                       0.0         0.0            0.0        74.1
# 23                       1.0         2.0            9.1        65.8
# 24                       3.0         3.0            8.2        61.9
# 25                       6.0         7.0            3.9        85.1
# 26                       0.0         2.0            0.0        61.6
# 27                       0.0         0.9            0.0        76.1
# 28                       0.0         0.7            1.0        49.9
# 29                       0.0         1.0            0.0        41.5
# ...                      ...         ...            ...         ...
# 16719                    0.0         0.0            1.0        30.0
# 16720                    1.0         1.0            1.0        45.0
# 16721                    0.0         0.0            1.0         7.9
# 16722                    0.0         0.0            0.0        14.0
# 16723                    0.0         0.0            4.0        29.1
# 16724                    0.0         0.0            0.0         6.0
# 16725                    0.0         0.0            0.0         5.0
# 16726                    0.0         0.0            1.0        12.0
# 16727                    0.0         0.0            0.0         8.0
# 16728                    0.0         0.0            0.0        11.0
# 16729                    0.0         0.0            0.0        19.5
# 16730                    2.0         0.0            0.0        15.7
# 16731                    0.0         0.0            0.0         0.0
# 16732                    0.0         0.0            0.0        13.0
# 16733                    0.0         0.0            0.0        13.0
# 16734                    0.0         0.0            0.0         3.0
# 16735                    0.0         0.0            1.0         8.0
# 16736                    0.0         0.0            0.0         7.0
# 16737                    0.0         0.0            0.0         8.0
# 16738                    2.3         0.0            2.0         3.0
# 16739                    0.0         0.0            1.0         0.0
# 16740                    0.0         1.0            1.0         0.5
# 16741                    0.8         0.0            0.0         1.4
# 16742                    1.0         1.0            1.0         0.0
# 16743                    1.0         0.0            0.0         1.9
# 16744                    0.0         0.0            0.0         1.3
# 16745                    2.7         0.9            1.8         2.9
# 16746                    0.0         0.0            0.0         1.0
# 16747                    0.0         0.0            0.0         4.5
# 16748                    0.0         0.0            0.0         1.0
#
#        FTE Count  Other (# )
# 0           69.6         0.0
# 1           39.8         0.0
# 2           29.5         0.0
# 3           51.6         0.0
# 4           83.5         1.0
# 5           58.8         0.0
# 6           48.5         0.0
# 7           49.4         0.0
# 8           58.2         0.0
# 9           60.3         0.0
# 10          48.1         0.0
# 11          29.8         0.0
# 12          48.0         0.0
# 13          49.1         0.0
# 14          59.9         0.0
# 15          58.0         0.0
# 16          78.0         0.0
# 17          89.1         0.0
# 18         133.7         0.0
# 19          56.9         0.9
# 20          57.3         0.0
# 21          83.1         0.0
# 22          74.1         0.0
# 23          80.3         2.5
# 24          78.4         2.3
# 25         104.3         2.3
# 26          63.6         0.0
# 27          77.0         0.0
# 28          51.6         0.0
# 29          42.5         0.0
# ...          ...         ...
# 16719       31.0         0.0
# 16720       48.0         0.0
# 16721        8.9         0.0
# 16722       14.0         0.0
# 16723       33.1         0.0
# 16724        6.0         0.0
# 16725        5.0         0.0
# 16726       13.0         0.0
# 16727        8.0         0.0
# 16728       11.0         0.0
# 16729       19.5         0.0
# 16730       17.7         0.0
# 16731        0.0         0.0
# 16732       13.0         0.0
# 16733       13.0         0.0
# 16734        3.0         0.0
# 16735        9.0         0.0
# 16736        7.0         0.0
# 16737        8.0         0.0
# 16738        7.3         0.0
# 16739        1.0         0.0
# 16740        2.5         0.0
# 16741        2.2         0.0
# 16742        3.0         0.0
# 16743        2.9         0.0
# 16744        1.3         0.0
# 16745        8.3         0.0
# 16746        1.0         0.0
# 16747        4.5         0.0
# 16748        1.0         0.0
#
# [82980 rows x 10 columns]

# %%
## Create df that matches job group code to the job category
jcl = list(set(job_categories['Job Group'].tolist()))
jobs = ["Student Support", "Related Service Providers", "Paraprofessionals", "All Staff", "District Leaders", "School Leaders", "Health", "Teachers", "Administrative Support"]
job_code_df = pd.DataFrame(list(map(list, zip(jcl,jobs))), columns = ["Job Group", "Job Category"])

# %%
job_categories = pd.merge(job_categories, job_code_df, on = "Job Group")

# %%
job_categories = job_categories.set_index("Org Code")

# %%
job_categories.to_csv("staff_raceeth_jobcategories_2011_2015.csv")
